# %% [markdown]
# # Employee Salary Analysation & Visualysation

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('emp_data.csv')

# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   name        100 non-null    object
#  2   age         100 non-null    int64
#  3   department  100 non-null    object
#  4   salary      100 non-null    int64
#  5   experience  100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB
# None

# %%
df
# Out:
#     id                name  age                department  salary  experience
# 0    4      Elden Strachan   78                   Support      22          52
# 1   42       Angus Moloney   83                 Marketing      61          39
# 2   87     Morgan Stienham   95                  Services       3          79
# 3   30       Alyce Robarts   39                     Legal      13          78
# 4   80    Enriqueta Drover   20                Accounting      43           7
# ..  ..                 ...  ...                       ...     ...         ...
# 95  94        Hunt Docksey   22  Research and Development      75          88
# 96  68     Lorenzo Perrott   27                     Sales      87          41
# 97  62  Elizabet MacTavish    2  Research and Development       7          44
# 98  55      Laney Nelthorp   66                Accounting      25          38
# 99  34  Prescott Wooddisse   16                     Sales      16          27
#
# [100 rows x 6 columns]

# %%
# Average Salary in Each Department
average_salary_by_department = df.groupby('department')['salary'].mean()
print("Average Salary in Each Department:")
print(average_salary_by_department)
# Out:
# Average Salary in Each Department:
# department
# Accounting                  54.000000
# Business Development        45.090909
# Engineering                 69.555556
# Human Resources             38.285714
# Legal                       40.555556
# Marketing                   53.000000
# Product Management          63.400000
# Research and Development    47.800000
# Sales                       58.000000
# Services                    18.000000
# Support                     57.750000
# Training                    63.000000
# Name: salary, dtype: float64

# %%
# Highest and Lowest Salary in the Company
highest_salary = df['salary'].max()
lowest_salary = df['salary'].min()
print("Highest Salary in the Company:", highest_salary)
print("Lowest Salary in the Company:", lowest_salary)
# Out:
# Highest Salary in the Company: 100
# Lowest Salary in the Company: 2

# %%
# Employee with the Maximum Salary
employee_with_max_salary = df[df['salary'] == highest_salary]
print("Employee with the Maximum Salary:")
print(employee_with_max_salary)
# Out:
# Employee with the Maximum Salary:
#     id              name  age          department  salary  experience
# 39  11  Kristi Coleyshaw   90  Product Management     100          73
# 50  66     Judas Howroyd   50  Product Management     100          75

# %%
# Count the Number of Employees in Each Department
employee_count_by_department = df['department'].value_counts()
print("Number of Employees in Each Department:")
print(employee_count_by_department)
# Out:
# Number of Employees in Each Department:
# department
# Accounting                  15
# Sales                       11
# Business Development        11
# Research and Development    10
# Engineering                  9
# Legal                        9
# Support                      8
# Marketing                    8
# Human Resources              7
# Training                     5
# Product Management           5
# Services                     2
# Name: count, dtype: int64

# %%
# Bar Chart Showing the Number of Employees in Each Department
import matplotlib.pyplot as plt
 
plt.figure(figsize=(10, 6))
employee_count_by_department.plot(kind='bar', title='Number of Employees in Each Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.show()

# %%
# Plot a Pie Chart Showing Salary Distribution by Department
total_salary_by_department = df.groupby('department')['salary'].sum()
plt.figure(figsize=(10, 6))
total_salary_by_department.plot(kind='pie', title='Salary Distribution by Department', autopct='%1.1f%%')
plt.show()

# %%
# Scatter Plot Showing Salary vs Experience
plt.figure(figsize=(10, 6))
plt.scatter(df['experience'], df['salary'])
plt.title('Salary vs Experience')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
# Employees Who Earn More Than the Average Salary
average_salary = df['salary'].mean()
employees_above_average_salary = df[df['salary'] > average_salary]
print("Employees Who Earn More Than the Average Salary:")
print(employees_above_average_salary)
# Out:
# Employees Who Earn More Than the Average Salary:
#     id                  name  age                department  salary  \
# 1   42         Angus Moloney   83                 Marketing      61
# 5   63           Trudi Ridde   17                     Sales      75
# 6   28       Justis Larmouth   20      Business Development      60
# 7   67         Ruperta Laise   63      Business Development      90
# 8   95           Dennet Jina   14                Accounting      79
# 10   2       Marylou Buessen   61                Accounting      66
# 12  61  Raynard Ravenscroftt   47                     Legal      65
# 13  19          Lulita Orgee   21                   Support      77
# 14  96           Perkin Yare   39               Engineering      90
# 15  49         Ulrich Ilchuk   56                 Marketing      63
# 16  22        Edik Hedingham   62                Accounting      91
# 17  15        Saleem Fernier   18                  Training      94
# ...

# %%
# Sort Employees Based on Salary in Descending Order
sorted_employees_by_salary = df.sort_values(by='salary', ascending=False)
print("Employees Sorted by Salary in Descending Order:")
print(sorted_employees_by_salary)
# Out:
# Employees Sorted by Salary in Descending Order:
#      id               name  age            department  salary  experience
# 50   66      Judas Howroyd   50    Product Management     100          75
# 39   11   Kristi Coleyshaw   90    Product Management     100          73
# 75   56     Diandra Ewdale   32              Training      99          47
# 37    5    Phillida Meijer   83           Engineering      99          29
# 67   95      Patric Frosch   76            Accounting      97          48
# ..  ...                ...  ...                   ...     ...         ...
# 26  100  Margarita Slocomb   23            Accounting       6          67
# 33   11      Damien Dudley   24                 Sales       3          35
# 2    87    Morgan Stienham   95              Services       3          79
# 55   59          Tove Pech   36            Accounting       2          95
# 51   13         Cosmo Grew   55  Business Development       2          39
#
# [100 rows x 6 columns]
